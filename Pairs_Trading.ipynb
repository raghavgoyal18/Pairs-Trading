# %% [markdown]
# ## <font color = 'black'> Importing Necessary Libraries

# %% [markdown]
# # Pairs Trading
# Pairs Trading is a market-neutral trading strategy which involves matching a long position with a short position in two securities which have a high level of positive cointegration. It is a form of statistical arbitrage i.e it looks at the relative price movement between the two securities.
#
# As it is a market-neutral strategy, it is independent of the trend being followed by the overall market (upwards or downwards or sideways). Instead, pairs trading works on the concept of mean-reversion. When two highly cointegrated securites deviate from their general trend, it is expected that they will return back to that trend in the future.
#
# The spread between the stock prices created during the deviation serves as an opportunity for profit. One can open a long position on the stock expected to move upwards and a short position on the stock expected to move downwards. If the pair performs as expected, it is a profitable trade.
#
# Even if the pair does not perform as expected, the trader will be able to mitigate some portion of their losses as the loss on one security will be offset by the profits on the other security. Hence, pairs trading also acts as a form of hedging and can be used to minimise losses.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# !pip install yfinance
# !pip install niftystocks
# !pip install quantstats

import yfinance as yf
from niftystocks import ns
import statsmodels.api as sm
import quantstats as qs
from statsmodels.tsa.stattools import coint

import warnings
warnings.filterwarnings('ignore')
# Out:
# Collecting niftystocks
#   Downloading niftystocks-0.1.2-py3-none-any.whl.metadata (6.5 kB)
# Downloading niftystocks-0.1.2-py3-none-any.whl (15 kB)
# Installing collected packages: niftystocks
# Successfully installed niftystocks-0.1.2
# Collecting quantstats
#   Downloading QuantStats-0.0.64-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from quantstats) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from quantstats) (1.26.4)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from quantstats) (0.13.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from quantstats) (3.10.0)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from quantstats) (1.13.1)
# Requirement already satisfied: tabulate>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.1.70 in /usr/local/lib/python3.11/dist-packages (from quantstats) (0.2.52)
# Requirement already satisfied: python-dateutil>=2.0 in /usr/local/lib/python3.11/dist-packages (from quantstats) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->quantstats) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->quantstats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->quantstats) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->quantstats) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->quantstats) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->quantstats) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.0.0->quantstats) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.0->quantstats) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.0->quantstats) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.0->quantstats) (1.17.0)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance>=0.1.70->quantstats) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance>=0.1.70->quantstats) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from yfinance>=0.1.70->quantstats) (5.3.1)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance>=0.1.70->quantstats) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance>=0.1.70->quantstats) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance>=0.1.70->quantstats) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance>=0.1.70->quantstats) (4.13.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.11/dist-packages (from yfinance>=0.1.70->quantstats) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance>=0.1.70->quantstats) (4.12.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib>=1.1->yfinance>=0.1.70->quantstats) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance>=0.1.70->quantstats) (2025.1.31)
# Downloading QuantStats-0.0.64-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: quantstats
# Successfully installed quantstats-0.0.64

# %% [markdown]
# ## <font color='black'>Fetching the Stock Price Data

# %%
# Collecting all tickers in nifty 100
tickers = ns.get_nifty100_with_ns()

# %%
# Fetching stock data for all tickers
stock_data = {}

start_date = "2017-06-01"
end_date = "2020-06-30"

for stock in tickers:
  ticker = yf.Ticker(stock)
  stock_data[stock] = ticker.history(start = start_date, end = end_date)['Close']

stock_prices = pd.DataFrame(stock_data)
# Out:
# ERROR:yfinance:$MOTHERSUMI.NS: possibly delisted; no timezone found
# ERROR:yfinance:Could not get exchangeTimezoneName for ticker 'UPL.NS' reason: 'chart'
# ERROR:yfinance:$UPL.NS: possibly delisted; no timezone found
# ERROR:yfinance:$HDFC.NS: possibly delisted; no timezone found
# ERROR:yfinance:$LTI.NS: possibly delisted; no timezone found
# ERROR:yfinance:$CADILAHC.NS: possibly delisted; no timezone found
# ERROR:yfinance:$ADANITRANS.NS: possibly delisted; no timezone found
# ERROR:yfinance:$MCDOWELL-N.NS: possibly delisted; no timezone found

# %%
stock_prices.dropna(axis=1, inplace=True)
stock_prices.sort_index(inplace=True)
stock_prices
# Out:
#                            HDFCBANK.NS      IGL.NS     IOC.NS   SHREECEM.NS  \
# Date
# 2017-06-01 00:00:00+05:30   765.152893   94.277962  81.981552  17182.076172
# 2017-06-02 00:00:00+05:30   767.807495   96.444618  82.169754  17478.802734
# 2017-06-05 00:00:00+05:30   768.418274   96.169914  83.605919  18123.423828
# 2017-06-06 00:00:00+05:30   770.015686   98.961281  84.111084  17661.890625
# 2017-06-07 00:00:00+05:30   770.884888   98.026405  84.655823  17592.351562
# ...                                ...         ...        ...           ...
# 2020-06-23 00:00:00+05:30  1000.585632  206.164062  42.178684  22401.652344
# 2020-06-24 00:00:00+05:30   991.177856  201.618515  41.116550  22214.611328
# 2020-06-25 00:00:00+05:30   987.578003  202.345810  40.148823  21724.916016
# 2020-06-26 00:00:00+05:30  1014.169312  200.959412  42.084278  22172.871094
# 2020-06-29 00:00:00+05:30  1032.984985  202.027618  41.116550  21993.806641
#
#                            TATACONSUM.NS  TATAMOTORS.NS  ADANIPORTS.NS  \
# Date
# 2017-06-01 00:00:00+05:30     139.575729     473.707214     333.933807
# 2017-06-02 00:00:00+05:30     141.819580     475.794250     342.253479
# 2017-06-05 00:00:00+05:30     141.911179     475.197937     345.265686
# 2017-06-06 00:00:00+05:30     140.125275     458.153839     345.648193
# 2017-06-07 00:00:00+05:30     142.460663     455.172363     343.401001
# ...                                  ...            ...            ...
# 2020-06-23 00:00:00+05:30     378.801422     103.755447     346.915253
# 2020-06-24 00:00:00+05:30     371.290314     104.152977     343.208618
# 2020-06-25 00:00:00+05:30     372.162598     103.159149     335.551392
# 2020-06-26 00:00:00+05:30     373.761749     100.773972     334.771057
# 2020-06-29 00:00:00+05:30     374.633972      98.836006     334.234528
#
#                            AMBUJACEM.NS    DABUR.NS  GODREJCP.NS  ...  \
# Date                                                              ...
# 2017-06-01 00:00:00+05:30    209.197372  264.007568   572.134155  ...
# 2017-06-02 00:00:00+05:30    209.284424  263.313782   573.284729  ...
# 2017-06-05 00:00:00+05:30    209.197372  264.423889   572.228760  ...
# 2017-06-06 00:00:00+05:30    204.584305  261.602020   572.890625  ...
# 2017-06-07 00:00:00+05:30    205.933426  262.573547   586.838684  ...
# ...                                 ...         ...          ...  ...
# 2020-06-23 00:00:00+05:30    174.878021  438.687286   649.085449  ...
# 2020-06-24 00:00:00+05:30    170.760590  435.291382   655.674500  ...
# 2020-06-25 00:00:00+05:30    168.543488  439.213440   660.164795  ...
# 2020-06-26 00:00:00+05:30    170.127121  440.361328   669.096497  ...
# 2020-06-29 00:00:00+05:30    169.719910  443.613647   671.243958  ...
#
#                              VEDL.NS   BIOCON.NS  INDUSTOWER.NS      ITC.NS  \
# Date
# 2017-06-01 00:00:00+05:30  85.275963  156.215561     277.333466  237.817551
# 2017-06-02 00:00:00+05:30  84.390930  158.566498     276.154083  241.602005
# 2017-06-05 00:00:00+05:30  84.593742  160.639908     281.903534  243.907043
# 2017-06-06 00:00:00+05:30  84.593742  161.880692     282.419464  238.989731
# 2017-06-07 00:00:00+05:30  85.995041  162.892899     282.456329  239.911697
# ...                              ...         ...            ...         ...
# 2020-06-23 00:00:00+05:30  49.280300  390.739868     201.805435  148.308990
# 2020-06-24 00:00:00+05:30  49.033897  384.235748     202.413422  153.097015
# 2020-06-25 00:00:00+05:30  49.840302  398.426544     198.418137  161.276535
# 2020-06-26 00:00:00+05:30  49.257904  395.962860     191.600082  155.770294
# 2020-06-29 00:00:00+05:30  48.361893  391.971680     190.427551  157.406250
#
#                            JSWSTEEL.NS     LUPIN.NS      M&M.NS  \
# Date
# 2017-06-01 00:00:00+05:30   173.252258  1094.620483  654.424377
# 2017-06-02 00:00:00+05:30   172.631744  1114.482788  651.325012
# 2017-06-05 00:00:00+05:30   168.864441  1104.074341  653.712708
# 2017-06-06 00:00:00+05:30   170.282730  1099.108765  648.087952
# 2017-06-07 00:00:00+05:30   173.207932  1102.403198  657.477905
# ...                                ...          ...         ...
# 2020-06-23 00:00:00+05:30   187.440308   912.968079  489.365356
# 2020-06-24 00:00:00+05:30   180.236435   896.906738  488.370270
# 2020-06-25 00:00:00+05:30   179.911087   910.388550  480.694305
# 2020-06-26 00:00:00+05:30   179.074493   902.114502  475.150574
# 2020-06-29 00:00:00+05:30   177.261932   900.021545  480.883850
#
#                            MUTHOOTFIN.NS  PETRONET.NS  SUNPHARMA.NS
# Date
# 2017-06-01 00:00:00+05:30     357.488098   159.324646    471.431610
# 2017-06-02 00:00:00+05:30     373.402618   160.385620    478.306366
# 2017-06-05 00:00:00+05:30     378.111542   157.040878    476.401855
# 2017-06-06 00:00:00+05:30     370.481354   161.878143    468.505157
# 2017-06-07 00:00:00+05:30     382.994904   158.245682    475.240601
# ...                                  ...          ...           ...
# 2020-06-23 00:00:00+05:30    1053.423706   205.055984    475.925964
# 2020-06-24 00:00:00+05:30    1038.905396   207.425232    460.662445
# 2020-06-25 00:00:00+05:30    1031.483154   205.964203    463.753113
# 2020-06-26 00:00:00+05:30    1017.665100   209.399567    456.430542
# 2020-06-29 00:00:00+05:30    1013.043884   207.504181    458.380066
#
# [756 rows x 86 columns]

# %% [markdown]
# ## <font color='black'> Finding Correlated Pairs (Pretest)

# %%
def find_correlated_pairs(df, threshold):

    corr_matrix = df.corr()
    n = corr_matrix.shape[0]
    result = pd.DataFrame(columns=['Asset 1', 'Asset 2', 'Correlation Coefficient'])

    for i in range(n):
        for j in range(i + 1, n):
            correlation = corr_matrix.iloc[i, j]
            if correlation >= threshold:
                result = pd.concat([result,
                                    pd.DataFrame({'Asset 1': [df.columns[i]],
                                                  'Asset 2': [df.columns[j]],
                                                  'Correlation Coefficient': [correlation]})],
                                   ignore_index=True)
    return result

# %%
corr_pairs = find_correlated_pairs(stock_prices, 0.9)
corr_pairs
# Out:
#           Asset 1        Asset 2  Correlation Coefficient
# 0     HDFCBANK.NS  BAJAJFINSV.NS                 0.951987
# 1     HDFCBANK.NS   KOTAKBANK.NS                 0.939886
# 2     HDFCBANK.NS  BAJFINANCE.NS                 0.930653
# 3   TATAMOTORS.NS         PNB.NS                 0.916492
# 4        DABUR.NS  HINDUNILVR.NS                 0.938993
# 5        DABUR.NS   NESTLEIND.NS                 0.900196
# 6        DABUR.NS  PIDILITIND.NS                 0.904527
# 7         PGHH.NS       TITAN.NS                 0.925651
# 8   HEROMOTOCO.NS   EICHERMOT.NS                 0.915297
# 9   HEROMOTOCO.NS        VEDL.NS                 0.910467
# 10  HINDUNILVR.NS  ASIANPAINT.NS                 0.922332
# 11  HINDUNILVR.NS   NESTLEIND.NS                 0.965830
# 12  HINDUNILVR.NS  ABBOTINDIA.NS                 0.908261
# 13  HINDUNILVR.NS  PIDILITIND.NS                 0.948760
# 14  HINDUNILVR.NS    DIVISLAB.NS                 0.926599
# 15  HINDUNILVR.NS       DMART.NS                 0.906697
# 16      NAUKRI.NS    RELIANCE.NS                 0.915217
# 17      NAUKRI.NS  ASIANPAINT.NS                 0.912291
# 18      NAUKRI.NS   NESTLEIND.NS                 0.930809
# 19      NAUKRI.NS  PIDILITIND.NS                 0.917123
# 20      NAUKRI.NS  BERGEPAINT.NS                 0.906443
# 21      NAUKRI.NS    DIVISLAB.NS                 0.917754
# 22         PEL.NS    BOSCHLTD.NS                 0.920421
# 23      GRASIM.NS   TATASTEEL.NS                 0.930330
# 24      GRASIM.NS        VEDL.NS                 0.955442
# 25   TATASTEEL.NS    HINDALCO.NS                 0.925623
# 26   TATASTEEL.NS        VEDL.NS                 0.927955
# 27        INFY.NS         TCS.NS                 0.961574
# 28        ONGC.NS   COALINDIA.NS                 0.925352
# 29        ONGC.NS        NTPC.NS                 0.913341
# 30  BAJAJFINSV.NS   KOTAKBANK.NS                 0.913823
# 31  BAJAJFINSV.NS  BAJFINANCE.NS                 0.961563
# 32   KOTAKBANK.NS  BAJFINANCE.NS                 0.952266
# 33   BRITANNIA.NS    JUBLFOOD.NS                 0.902350
# 34      COLPAL.NS  ASIANPAINT.NS                 0.902569
# 35   ICICIBANK.NS  BAJFINANCE.NS                 0.922507
# 36  ASIANPAINT.NS   NESTLEIND.NS                 0.938901
# 37  ASIANPAINT.NS  PIDILITIND.NS                 0.937630
# 38  ASIANPAINT.NS  BERGEPAINT.NS                 0.955953
# 39   NESTLEIND.NS  ABBOTINDIA.NS                 0.971208
# 40   NESTLEIND.NS  PIDILITIND.NS                 0.951742
# 41   NESTLEIND.NS  BERGEPAINT.NS                 0.944572
# 42   NESTLEIND.NS    DIVISLAB.NS                 0.945122
# 43   NESTLEIND.NS       DMART.NS                 0.939179
# 44   NESTLEIND.NS  TORNTPHARM.NS                 0.906888
# 45  ABBOTINDIA.NS  BERGEPAINT.NS                 0.926218
# 46  ABBOTINDIA.NS    DIVISLAB.NS                 0.925452
# 47  ABBOTINDIA.NS       DMART.NS                 0.939934
# 48  ABBOTINDIA.NS  TORNTPHARM.NS                 0.913599
# 49  PIDILITIND.NS    DIVISLAB.NS                 0.916859
# 50     DRREDDY.NS  TORNTPHARM.NS                 0.924949
# 51    DIVISLAB.NS  TORNTPHARM.NS                 0.936612

# %% [markdown]
# After performing correlation test with a threshold of 0.9, we have obtained 50 pairs of stocks out of 89*88/2 = 3916 possible pairs for further consideration.

# %% [markdown]
# ## <font color='black'> Finding Cointegrated Pairs

# %%
def finding_cointegrated_pairs(df, threshold):

    result = []
    for i in range(len(df)):
        asset1 = df['Asset 1'][i]
        asset2 = df['Asset 2'][i]
        p_value = coint(stock_prices[asset1], stock_prices[asset2])[1]
        if p_value <= threshold:
            result.append({
                'Asset 1': asset1,
                'Asset 2': asset2,
                'Correlation': df['Correlation Coefficient'][i],
                'p-value': p_value
            })
    return pd.DataFrame(result)

# %%
coint_pairs = finding_cointegrated_pairs(corr_pairs, 0.01)
coint_pairs
# Out:
#          Asset 1        Asset 2  Correlation   p-value
# 0        PGHH.NS       TITAN.NS     0.925651  0.000843
# 1  HEROMOTOCO.NS        VEDL.NS     0.910467  0.005902
# 2  HINDUNILVR.NS  PIDILITIND.NS     0.948760  0.004872
# 3      GRASIM.NS        VEDL.NS     0.955442  0.008603
# 4        INFY.NS         TCS.NS     0.961574  0.000090
# 5        ONGC.NS   COALINDIA.NS     0.925352  0.005338
# 6        ONGC.NS        NTPC.NS     0.913341  0.001108
# 7   KOTAKBANK.NS  BAJFINANCE.NS     0.952266  0.002839
# 8    DIVISLAB.NS  TORNTPHARM.NS     0.936612  0.009933

# %% [markdown]
# After performing cointegration test with a threshold of 0.01, we have obtained 9 pairs of stocks out of 8 pairs for further consideration.

# %% [markdown]
# ## <font color='black'>Calculating Hedge Ratios

# %%
def calculate_hedge_ratio(df):
    hedge_ratio = []
    n = df.shape[0]
    for i in range(n):
        covariance = np.cov(stock_prices[df.iloc[i, 0]], stock_prices[df.iloc[i, 1]])[0, 1]
        variance = np.var(stock_prices[df.iloc[i, 0]])
        hedge_ratio.append(covariance/variance)
    return hedge_ratio

# %%
coint_pairs['Hedge Ratio'] = calculate_hedge_ratio(coint_pairs)

# %% [markdown]
# To choose from remaining 9 pairs, we will choose the pair whose hedge ratio is nearest to 1

# %%
coint_pairs['criterion'] = np.abs(coint_pairs['Hedge Ratio'] - 1)
coint_pairs.sort_values(by='criterion', inplace=True)
coint_pairs
# Out:
#          Asset 1        Asset 2  Correlation   p-value  Hedge Ratio  criterion
# 5        ONGC.NS   COALINDIA.NS     0.925352  0.005338     1.000888   0.000888
# 2  HINDUNILVR.NS  PIDILITIND.NS     0.948760  0.004872     0.690501   0.309499
# 6        ONGC.NS        NTPC.NS     0.913341  0.001108     0.448586   0.551414
# 8    DIVISLAB.NS  TORNTPHARM.NS     0.936612  0.009933     0.334497   0.665503
# 0        PGHH.NS       TITAN.NS     0.925651  0.000843     0.198924   0.801076
# 3      GRASIM.NS        VEDL.NS     0.955442  0.008603     0.128576   0.871424
# 1  HEROMOTOCO.NS        VEDL.NS     0.910467  0.005902     0.055760   0.944240
# 4        INFY.NS         TCS.NS     0.961574  0.000090     3.069432   2.069432
# 7   KOTAKBANK.NS  BAJFINANCE.NS     0.952266  0.002839     3.809985   2.809985

# %%
sns.lineplot(stock_prices[coint_pairs.iloc[0, 0]], label=coint_pairs.iloc[0, 0])
sns.lineplot(stock_prices[coint_pairs.iloc[0, 1]], label=coint_pairs.iloc[0, 1])
plt.title('Closing Price of selected pair')
plt.ylabel('Closing Price')
plt.xlabel('Date')
sns.set_style('whitegrid')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## <font color='black'>Selected Pair of Stocks

# %%
stock1 = coint_pairs.iloc[0, 1]
stock2 = coint_pairs.iloc[0, 0]
hedge_ratio = coint_pairs.iloc[1, 4]
print(stock1, stock2, hedge_ratio)
# Out:
# COALINDIA.NS ONGC.NS 0.6905010963389767

# %%
startdate = "2020-07-01"
enddate = "2023-07-31"

stockprices = yf.download([stock1, stock2], start=startdate, end=enddate)['Close']
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
stockprices
# Out:
# Ticker      COALINDIA.NS     ONGC.NS
# Date
# 2020-07-01     86.038887   61.022701
# 2020-07-02     85.878189   62.084618
# 2020-07-03     86.938805   62.501816
# 2020-07-06     87.324501   63.525795
# 2020-07-07     85.396095   62.160480
# ...                  ...         ...
# 2023-07-24    201.895905  154.956512
# 2023-07-25    201.021729  156.768875
# 2023-07-26    201.502533  156.723557
# 2023-07-27    200.234940  154.956512
# 2023-07-28    198.530273  155.681458
#
# [767 rows x 2 columns]

# %% [markdown]
# ### <font color='black'> Calculating spread

# %%
spread = -stockprices[stock1]*hedge_ratio + stockprices[stock2]

# %%
sns.lineplot(spread, label='spread')
plt.axhline(spread.mean(), color='black', linestyle='--', label='Mean Spread')
plt.title("Pair's Spread")
plt.ylabel('Spread')
plt.xlabel('Date')
sns.set_style('whitegrid')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <font color='black'>Calculating z-score

# %%
def zscore(series):
    lookback = 21
    scores = []
    for i in range(lookback, len(series)):
      window = series[i-lookback:i]
      scores.append((series[i]-window.mean())/window.std())
    return pd.Series(scores, index = series.index[lookback:])

# %%
zscore = zscore(spread)

# %%
sns.lineplot(zscore, label = 'zscore')
plt.title("zscore of spread")
plt.ylabel('zscore')
plt.xlabel('Date')
sns.set_style('whitegrid')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## <font color='black'>Trading Strategy

# %% [markdown]
# ### <font color='black'>Generation of Signals

# %%
# Create a dataframe for trading signals
signals = pd.DataFrame()
signals[stock1] = stockprices[stock1]
signals[stock2] = stockprices[stock2]
signals['spread'] = spread
signals['zscore'] = zscore

signals.dropna(inplace = True)

signals['signal1'] = np.select([signals['zscore'] > 1, signals['zscore'] < -1], [1, -1], default = 0)
signals['position1'] = 0

signals['position1'] = signals['signal1'].diff()
if signals['signal1'][0] != 0:
    signals['position1'][0] = signals['signal1'][0]
signals['signal2'] = -signals['signal1']
signals['position2'] = -signals['position1']

signals.dropna(inplace = True)
signals

signals.to_csv('signals.csv')

# %% [markdown]
# ### <font color='black'>Visualizing Long and Short Positions

# %%
fig = plt.figure(figsize=(14, 6))
bx = fig.add_subplot(111)
series = bx.plot(signals['zscore'], c='#4abdac')
a = (signals['position1'] == 1) | (signals['position1'] == 2)
b = (signals['position1'] == -1) | (signals['position1'] == -2)
long = bx.plot(signals['zscore'][a], lw = 0, marker = '^', markersize = 7, c = 'g', alpha = 0.7)
short = bx.plot(signals['zscore'][b], lw = 0, marker = 'v', markersize = 7, c = 'r', alpha = 0.7)
plt.title(f'{stock1} / {stock2}')
plt.legend(['Z-Score', 'Position 1', 'Position 2'])
sns.set_style('whitegrid')
plt.tight_layout()
plt.show()

# %% [markdown]
# Position 1 --  Buy COALINDIA.NS and Sell ONGC.NS <br>
# Position 2 -- Sell COALINDIA.NS and Buy ONGC.NS

# %%
fig = plt.figure(figsize=(14,6))
bx = fig.add_subplot(111)
l1 = bx.plot(signals[stock1], c='#4abdac')
u1 = bx.plot(signals[stock1][a], lw=0, marker='^', markersize=7, c='g',alpha=0.9)
u2, = bx.plot(signals[stock1][b], lw=0, marker='v', markersize=7, c='r',alpha=0.9)
plt.title('Long and Short positions on '+ str(stock1))
plt.legend(['Price', 'Long', 'Short'])
sns.set_style('whitegrid')
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(14,6))
bx = fig.add_subplot(111)
l1 = bx.plot(signals[stock2], c='#4abdac')
u1 = bx.plot(signals[stock2][b], lw=0, marker='^', markersize=7, c='g',alpha=0.9)
u2, = bx.plot(signals[stock2][a], lw=0, marker='v', markersize=7, c='r',alpha=0.9)
plt.title('Long and Short positions on '+ str(stock2))
plt.legend(['Price', 'Long', 'Short'])
sns.set_style('whitegrid')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <font color='black'>Visualising daily closing prices on backtesting period

# %%
sns.lineplot(stockprices[stock1], label=stock1)
sns.lineplot(stockprices[stock2], label=stock2)
plt.title('Daily Closing Price on backtesting period')
plt.ylabel('Closing Price')
plt.xlabel('Date')
sns.set_style('whitegrid')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <font color='black'>Generating Portfolio

# %%
initial_capital = 100000

w1 = 0.5
w2 = 1 - w1

# Shares to buy for each stock
shares1 = (w1*initial_capital)// (signals[stock1][0])
shares2 = (w2*initial_capital)// (signals[stock2][0])

#PnL for stock 1
portfolio = pd.DataFrame()
portfolio['holdings1'] = signals['position1'].cumsum() * signals[stock1] * shares1
portfolio['cash1'] = w1*initial_capital - (signals['position1'] * signals[stock1] * shares1).cumsum()
portfolio['total1'] = portfolio['holdings1'] + portfolio['cash1']
portfolio['return1'] = portfolio['total1'].pct_change()

# PnL for stock 2
portfolio['holdings2'] = signals['position2'].cumsum() * signals[stock2] * shares2
portfolio['cash2'] = w2*initial_capital - (signals['position2'] * signals[stock2] * shares2).cumsum()
portfolio['total2'] = portfolio['holdings2'] + portfolio['cash2']
portfolio['return2'] = portfolio['total2'].pct_change()

# Total PnL
portfolio['total'] = portfolio['total1'] + portfolio['total2']
portfolio = portfolio.dropna()

# %%
portfolio
# Out:
#                 holdings1         cash1        total1   return1  \
# Date
# 2020-08-03  -49603.908607  99603.908607  50000.000000  0.000000
# 2020-08-04  -49739.123520  99603.908607  49864.785088 -0.002704
# 2020-08-05  -49623.221748  99603.908607  49980.686859  0.002324
# 2020-08-06       0.000000  49826.145050  49826.145050 -0.003092
# 2020-08-07       0.000000  49826.145050  49826.145050  0.000000
# ...                   ...           ...           ...       ...
# 2023-07-24  121339.438629 -58409.428375  62930.010254  0.016549
# 2023-07-25  120814.058838 -58409.428375  62404.630463 -0.008349
# 2023-07-26  121103.022308 -58409.428375  62693.593933  0.004630
# 2023-07-27  120341.198685 -58409.428375  61931.770309 -0.012152
# 2023-07-28  119316.694336 -58409.428375  60907.265961 -0.016542
#
#                 holdings2          cash2         total2   return2  \
# Date
# 2020-08-03   48417.592052    1582.407948   50000.000000  0.000000
# 2020-08-04   48545.177383    1582.407948   50127.585331  0.002552
# 2020-08-05   49087.401405    1582.407948   50669.809353  0.010817
# 2020-08-06       0.000000   51371.511028   51371.511028  0.013849
# 2020-08-07       0.000000   51371.511028   51371.511028  0.000000
# ...                   ...            ...            ...       ...
# 2023-07-24 -130318.426971  232797.290230  102478.863258 -0.003335
# 2023-07-25 -131842.623978  232797.290230  100954.666252 -0.014873
# 2023-07-26 -131804.511032  232797.290230  100992.779198  0.000378
# 2023-07-27 -130318.426971  232797.290230  102478.863258  0.014715
# 2023-07-28 -130928.105774  232797.290230  101869.184456 -0.005949
#
#                     total
# Date
# 2020-08-03  100000.000000
# 2020-08-04   99992.370419
# 2020-08-05  100650.496212
# 2020-08-06  101197.656078
# 2020-08-07  101197.656078
# ...                   ...
# 2023-07-24  165408.873512
# 2023-07-25  163359.296715
# 2023-07-26  163686.373131
# 2023-07-27  164410.633568
# 2023-07-28  162776.450417
#
# [744 rows x 9 columns]

# %% [markdown]
# ### <font color='black'>Visualizing Portfolio PnL

# %%
fig = plt.figure(figsize=(14,6),)
ax = fig.add_subplot(111)
l1, = ax.plot(portfolio['total'], c='g')
ax.set_ylabel('Asset Value')
ax.yaxis.labelpad=15
ax.set_xlabel('Date')
ax.xaxis.labelpad=15
plt.title('Portfolio Performance PnL')
plt.legend(['Total Portfolio Value'])
sns.set_style('whitegrid')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <font color='black'>Performance Metrics of Trading Strategy on Selected Pair of Stocks

# %%
final_portfolio = portfolio['total'].iloc[-1]
initial_portfolio = portfolio['total'].iloc[0]
delta = len(portfolio.index)
print('Number of trading days = ', delta)
YEAR_DAYS = 252
returns = (final_portfolio/initial_portfolio) ** (YEAR_DAYS/delta) - 1
print('CAGR = {:.3f}%' .format(returns * 100))
# Out:
# Number of trading days =  744
# CAGR = 17.942%

# %%
cummulative_return = (final_portfolio/initial_portfolio)-1
print('Cummulative Return = {:.3f}%' .format(cummulative_return * 100))
# Out:
# Cummulative Return = 62.776%

# %%
drawdown = qs.stats.max_drawdown(portfolio['total'])
print("Maximmum Drawdown of trading strategy:", np.round(drawdown*100, 3), "%")
# Out:
# Maximmum Drawdown of trading strategy: -15.809 %

# %%
sharpe_ratio = qs.stats.sharpe(portfolio['total'])
print("Sharpe Ratio:", np.round(sharpe_ratio, 3))
# Out:
# Sharpe Ratio: 1.165

# %%
print('Frequency of trades:', np.round(abs(signals['position1']).sum()/len(portfolio)*252, 3), 'per year')
